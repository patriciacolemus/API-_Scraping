# %% [markdown]
# ## **Vaccine Tweets**

# %%
## Libraries ## 
import credentials
import tweepy
import json
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### **Tweets search**

# %%
# Authorization # 
auth = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
api = tweepy.API(auth)

# %%
# Query: 6000 tweets including any word from: vacuna,vacunas, vacunación, vacunar; 
# in Spanish, both popular and real time results. Filter retweets
id= None 
tweets = []
for tweet in tweepy.Cursor(api.search_tweets,
                       q='vacuna OR vacunas OR vacunación OR vacunar' +  " -filter:retweets",
                       lang="es",
                       result_type='mixed',    #result_type:popular,recent,mixed.
                       max_id=id).items(6000): #max_id allows every search to have different entries
    tweets.append(tweet)
    #print(json.dumps(tweet._json, indent=2))
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /var/folders/gf/6xv8ryqj03g_vxjpsh0dvl280000gn/T/ipykernel_26792/936974345.py in <module>
#       3 id= None
#       4 tweets = []
# ----> 5 for tweet in tweepy.Cursor(api.search_tweets,
#       6                        q='vacuna OR vacunas OR vacunación OR vacunar' +  " -filter:retweets",
#       7                        lang="es",
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1266         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/api-reference/get-search-tweets
#    1267         """
# -> 1268         return self.request(
#    1269             'GET', 'search/tweets', endpoint_parameters=(
#    1270                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# /opt/homebrew/lib/python3.9/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     261                 raise NotFound(resp)
#     262             if resp.status_code == 429:
# --> 263                 raise TooManyRequests(resp)
#     264             if resp.status_code >= 500:
#     265                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
len(tweets)
# Out:
# 4244

# %%
# Create a dataframe
data = [[tweet.user.id_str, tweet.user.screen_name, tweet.text, tweet.id_str, tweet.created_at, tweet.retweet_count,
         tweet.favorite_count, tweet.user.description,tweet.user.verified, tweet.user.followers_count, 
         tweet.user.friends_count, tweet.entities['hashtags'], tweet.entities['user_mentions'], 
         tweet.entities['urls']] for tweet in tweets]


# Rename the variables
df = pd.DataFrame(data=data, columns=['user_id', 'screen_name', 'text', 'tweet_id', 'date', 'retweet_count',
                                      'favorite_count', 'user_description', 'account_verified', 
                                      'followers', 'friends', 'hashtags', 'mentions', 'links'])

# %%
#df.tail(5)

# %%
df.to_csv('Tweets_281121_vacuna.csv', index= False)

# %%
df = pd.read_csv('Tweets_281121_vacuna.csv')

# %% [markdown]
# ### **Data cleaning**

# %%
# 1) Data exploration
df.head(2) 
df.shape 
df.info() 
df.columns
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2500 non-null   int64
#  1   screen_name       2500 non-null   object
#  2   text              2500 non-null   object
#  3   tweet_id          2500 non-null   int64
#  4   date              2500 non-null   object
#  5   retweet_count     2500 non-null   int64
#  6   favorite_count    2500 non-null   int64
#  7   user_description  2094 non-null   object
#  8   account_verified  2500 non-null   bool
#  9   followers         2500 non-null   int64
#  10  friends           2500 non-null   int64
#  11  hashtags          2500 non-null   object
#  12  mentions          2500 non-null   object
#  13  links             2500 non-null   object
# dtypes: bool(1), int64(6), object(7)
# memory usage: 256.5+ KB
# Index(['user_id', 'screen_name', 'text', 'tweet_id', 'date', 'retweet_count',
#        'favorite_count', 'user_description', 'account_verified', 'followers',
#        'friends', 'hashtags', 'mentions', 'links'],
#       dtype='object')

# %%
null_cols = df.isnull().sum()
null_cols

# There are no null rows, however there are '[]' to fill the empty entries. 

# Replace '[]' for 0
df.loc[(df.hashtags == '[]'), 'hashtags'] = 0
df.loc[(df.mentions == '[]'), 'mentions'] = 0
df.loc[(df.user_description == '[]'), 'user_description'] = 0
df.loc[(df.links == '[]'), 'links'] = 0

# %%
# Null entries
null_cols[null_cols > 0]
drop_cols = list(null_cols[null_cols > 100].index)
df = df.drop(drop_cols, axis=1)

# %%
### TWEETS

# Text
uniqueTweet = df.text.nunique() #1,570/2,500
print('Unique tweets:', uniqueTweet)

# Duplicate tweets 
repeatedTweet = df['text'].duplicated().sum() 
print('Repeated tweets:', repeatedTweet)

# Tweet_id
uniqueStatus = df.tweet_id.nunique()
print('Unique status:', uniqueStatus)

repeatedStatus = df['tweet_id'].duplicated().sum() 
print('Repeated status:', repeatedStatus) 

# While every tweet has a unique ID, the tweet content(text) can be repeated.
# Whithin this sample, all the tweets are original content
# Out:
# Unique tweets: 2500
# Repeated tweets: 0
# Unique status: 2500
# Repeated status: 0

# %%
### USERS

# Unique users
uniqueUsers = df.user_id.nunique() 
duplicateUsers = df['user_id'].duplicated().sum() 
print('Number of duplicate users:', duplicateUsers, 'from:', uniqueUsers)

# Add a new variable to identify unique or duplicate users
conteos = df.user_id.value_counts()
conteos[df.user_id]
df['User_tag'] = np.where(conteos[df.user_id] == 1, 'Unique','Duplicate')
# Out:
# Number of duplicate users: 562 from: 1938

# %%
# Identify the users with more followers 
pd.cut(df.followers, 5)
tag = ['Very popular', 'Popular', 'Few followers', 'Unpopular', 'No followers'] 
pd.cut(df.followers, 5, labels = tag) 
pd.cut(df.followers, 5, labels = tag).value_counts()

# Add a new variable to identify the followers range of the users
df['Popularity'] = pd.cut(df.followers, 5, labels=tag)

# %%
# Calculate 'engagement' (likes and retweets) 
df['Engagement'] = df[['retweet_count', 'favorite_count']].mean(axis=1)

# Change the 'Engagement' type of variable
df.Engagement.astype('int64')
# Out:
# 0       11058
# 1        2615
# 2        6294
# 3           0
# 4           0
#         ...
# 2495        0
# 2496        0
# 2497        0
# 2498        8
# 2499        0
# Name: Engagement, Length: 2500, dtype: int64

# %%
# Identify the most popular users 
pd.cut(df.Engagement, 4)
tag = ['Very popular', 'Popular', 'Not very popular', 'Unpopular'] 
pd.cut(df.Engagement, 4, labels = tag) 
pd.cut(df.Engagement, 4, labels = tag).value_counts()
# Out:
# Very popular        2498
# Not very popular       1
# Unpopular              1
# Popular                0
# Name: Engagement, dtype: int64

# %%
# Compare engagement verified accounts and non-verified accounts
# Out:
#                user_id      screen_name  \
# 0            316273207     doctormacias
# 1            126465001      FrayJosepho
# 2  1154180084078501889         HLGatell
# 5  [{'url': 'https://t.co/F4ZR0wEJGL', 'expanded_...   Unique  Very popular
# 6  [{'url': 'https://t.co/iLcakSCNQ6', 'expanded_...   Unique  Very popular
# 7                                                  0   Unique  Very popular
# 8                                                  0   Unique  Very popular
# 9  [{'url': 'https://t.co/nMEV35SudU', 'expanded_...   Unique  Very popular
#
#    Description_TF  hashtags_TF  mentions_TF  links_TF  Engagement
# 0            True        False        False      True     11058.5
# 1            True        False        False      True      2615.5
# 2            True        False        False      True      6294.5
# 3            True        False        False      True         0.0
# 4            True        False         True      True         0.0
# 5            True        False        False      True         0.0
# 6            True        False         True      True         0.0
# 7            True        False        False     False         0.0
# 8            True        False        False     False         0.0
# 9            True        False        False      True         0.0

# %%
# Delete favorite_count and retweet_count
df.drop(columns= 'favorite_count', inplace = True)
df.drop(columns= 'retweet_count', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gf/6xv8ryqj03g_vxjpsh0dvl280000gn/T/ipykernel_26792/3142274575.py in <module>
#       1 # Delete favorite_count and retweet_count
# ----> 2 df.drop(columns= 'favorite_count', inplace = True)
#       3 df.drop(columns= 'retweet_count', inplace = True)
#       4
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['favorite_count'] not found in axis"

# %%
# Popular users + popular tweets
popular = df[(df.Popularity == 'Very popular') & (df.favorite_count >= 100) | (df.retweet_count >= 100)]
# Most popular users get more engagement. 

weird = df[(df.Popularity == 'No followers') & (df.favorite_count >= 100)]
weird
# Out:
#      user_id screen_name                                               text  \
# 189  7996082     el_pais  🔴 ÚLTIMA HORA | Países Bajos detecta 61 pasaje...
# 368  7996082     el_pais  🔴 DIRECTO | Alemania confirma 67.000 nuevos co...
#
#                 tweet_id                       date  retweet_count  \
# 189  1464528628335751171  2021-11-27 09:36:49+00:00            419
# 368  1464526120104169477  2021-11-27 09:26:51+00:00            104
#
#      favorite_count                                   user_description  \
# 189             606  La mejor información en español. Con nuestra m...
# 368             112  La mejor información en español. Con nuestra m...
#
#      account_verified  followers  friends hashtags mentions  \
# 189              True    8209200      791       []       []
# 368              True    8209200      791       []       []
#
#                                                  links   User_tag  \
# 189  [{'url': 'https://t.co/ITCQNyR4hN', 'expanded_...  Duplicate
# 368  [{'url': 'https://t.co/iDd1rUqaae', 'expanded_...  Duplicate
#
#        Popularity  Description_TF  hashtags_TF  mentions_TF  links_TF
# 189  No followers            True        False        False      True
# 368  No followers            True        False        False      True

# %%
# Change the date
df.date.astype('datetime64[ns]')
# Out:
# 0      2021-11-27 09:45:58
# 1      2021-11-27 13:38:45
# 2      2021-11-28 02:26:46
# 3      2021-11-28 20:19:54
# 4      2021-11-28 20:19:54
#                ...
# 2495   2021-11-27 06:52:29
# 2496   2021-11-27 06:52:20
# 2497   2021-11-27 06:52:19
# 2498   2021-11-27 06:52:19
# 2499   2021-11-27 06:52:18
# Name: date, Length: 2500, dtype: datetime64[ns]

# %%
df.drop_duplicates(subset=['user_id','text','date', 'account_verified', 'hashtags', 'mentions', 'links', 'User_tag', 'Popularity',
       'Description_TF', 'hashtags_TF', 'mentions_TF', 'links_TF', 'Engagement'],keep='first', inplace=True)
